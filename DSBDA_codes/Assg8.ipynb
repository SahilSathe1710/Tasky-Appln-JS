# %%
import seaborn as sns
print (sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titan = df[['pclass','sex','age','alone','fare','survived']]
titan
# Out:
#      pclass     sex   age  alone     fare  survived
# 0         3    male  22.0  False   7.2500         0
# 1         1  female  38.0  False  71.2833         1
# 2         3  female  26.0   True   7.9250         1
# 3         1  female  35.0  False  53.1000         1
# 4         3    male  35.0   True   8.0500         0
# ..      ...     ...   ...    ...      ...       ...
# 886       2    male  27.0   True  13.0000         0
# 887       1  female  19.0   True  30.0000         1
# 888       3  female   NaN  False  23.4500         0
# 889       1    male  26.0   True  30.0000         1
# 890       3    male  32.0   True   7.7500         0
#
# [891 rows x 6 columns]

# %%
titan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    891 non-null    int64
#  1   sex       891 non-null    object
#  2   age       714 non-null    float64
#  3   alone     891 non-null    bool
#  4   fare      891 non-null    float64
#  5   survived  891 non-null    int64
# dtypes: bool(1), float64(2), int64(2), object(1)
# memory usage: 35.8+ KB

# %%
titan.sample(10)
# Out:
#      pclass     sex   age  alone      fare  survived
# 420       3    male   NaN   True    7.8958         0
# 579       3    male  32.0   True    7.9250         1
# 332       1    male  38.0  False  153.4625         0
# 708       1  female  22.0   True  151.5500         1
# 8         3  female  27.0  False   11.1333         1
# 886       2    male  27.0   True   13.0000         0
# 268       1  female  58.0  False  153.4625         1
# 95        3    male   NaN   True    8.0500         0
# 247       2  female  24.0  False   14.5000         1
# 477       3    male  29.0  False    7.0458         0

# %%
# Finding patterns
titan.pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titan.survived.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# Plotting histogram
sns.histplot(titan['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
# Countplot function
sns.countplot(x=titan['age'])
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
sns.histplot(titan['fare'] , bins = 10 , kde = True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>
